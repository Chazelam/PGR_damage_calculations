# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# No buffs = 1160
#
# Only Karen SS3 - 2020
#
# Only Karen SSS - 2301

# %%
skill_scaling           = 411.76 / 4 # Luna anig orb
base_atk_stat           = 1221 # Luna`s atk
atk_increase            = 0
final_atk               = 0
elemental__dmg_increase = 5 # Luna SS
base_dmg_increase       = 20.59 # class passive
extra_dmg_bonus         = 0
elemental__resistance   = 23.9 - 10 - 8 - 15 - 10 # Dummy res + Sig + Res + QTE + SSS(Leap)
extra_dmg_reduction     = 4 - 20.59 - 5 # Dummy res + class passive + SSS

# Формула
final_dmg_output = skill_scaling/100 * (base_atk_stat * (1 + atk_increase) + final_atk) \
                   * (1 + elemental__dmg_increase/100) \
                   * (1 + base_dmg_increase/100) * (1 + extra_dmg_bonus/100) \
                   * (1 - elemental__resistance/100) \
                   * (1 - extra_dmg_reduction/100)

print("Final DMG Output:", final_dmg_output)
# Out:
# Final DMG Output: 2304.6768637422083

# %% [markdown]
# # All Karenina: Scire Buffs:
#
# 43% Dark resistance
# - 15% Base kit
# - 10% Sig
# - 10% SSS
# - 8% all elements From Res
#
# 23% Lightning
# - 15% Leap
# - 8% all elements From Res
#
# 25.59 - extra dmg reduction Base kit
